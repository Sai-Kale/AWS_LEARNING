# %% [markdown]
# <a href="https://colab.research.google.com/github/Sai-Kale/AWS_LEARNING/blob/master/AWS_EKS/CKA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Certified Kubernetes Administrator:**
#
# **Cluster Architecture:**

# %% [markdown]
# ![K8S.PNG](data:image/png;base64,...)
